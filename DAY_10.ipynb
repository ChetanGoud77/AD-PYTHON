# %% [markdown]
# <a href="https://colab.research.google.com/github/ChetanGoud77/PYTHON/blob/main/DAY_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
k=[4,2.56789,9,87.9999,40,'HYDERABAD']

# %%
k
# Out:
# [4, 2.56789, 9, 87.9999, 40, 'HYDERABAD']

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.Series(k)
# Out:
# 0            4
# 1      2.56789
# 2            9
# 3      87.9999
# 4           40
# 5    HYDERABAD
# dtype: object

# %%
k=[4,2.56789,9,87.9999,40]

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.Series(k)
# Out:
# 0     4.00000
# 1     2.56789
# 2     9.00000
# 3    87.99990
# 4    40.00000
# dtype: float64

# %%
a=np.random.randint(20,50,15)
a
# Out:
# array([40, 49, 40, 27, 44, 42, 30, 31, 45, 38, 33, 40, 36, 46, 31])

# %%
a.ndim
# Out:
# 2

# %%
pd.Series(a)
# Out:
# 0     40
# 1     49
# 2     40
# 3     27
# 4     44
# 5     42
# 6     30
# 7     31
# 8     45
# 9     38
# 10    33
# 11    40
# 12    36
# 13    46
# 14    31
# dtype: int64

# %%
a[4:9]
# Out:
# array([44, 42, 30, 31, 45])

# %%
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[165, 144, 141, 153, 143],
#        [170, 106, 187, 176, 132],
#        [130, 100, 128, 105, 196],
#        [187, 197, 108, 161, 190],
#        [131, 105, 154, 179, 179],
#        [115, 117, 136, 165, 184]])

# %%
np.random.seed(77)
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[187, 195, 184, 184, 137],
#        [124, 131, 196, 157, 139],
#        [144, 119, 132, 159, 154],
#        [136, 147, 178, 115, 110],
#        [171, 135, 159, 101, 111],
#        [181, 106, 120, 156, 197]])

# %%
b.shape
# Out:
# (6, 5)

# %%
pd.DataFrame(b)
# Out:
#      0    1    2    3    4
# 0  187  195  184  184  137
# 1  124  131  196  157  139
# 2  144  119  132  159  154
# 3  136  147  178  115  110
# 4  171  135  159  101  111
# 5  181  106  120  156  197

# %%
pd.DataFrame(b,columns=['A','B','C','D','E'])
# Out:
#      A    B    C    D    E
# 0  187  195  184  184  137
# 1  124  131  196  157  139
# 2  144  119  132  159  154
# 3  136  147  178  115  110
# 4  171  135  159  101  111
# 5  181  106  120  156  197

# %%
pd.DataFrame(b,columns=['name','age','class','address','pincode'],index=['a','b','c','d','e','f'])
# Out:
#    name  age  class  address  pincode
# a   187  195    184      184      137
# b   124  131    196      157      139
# c   144  119    132      159      154
# d   136  147    178      115      110
# e   171  135    159      101      111
# f   181  106    120      156      197

# %%
df.iloc[0,0]
# Out:
# 0.6735654581007056
