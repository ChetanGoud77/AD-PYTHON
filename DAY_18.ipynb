# %% [markdown]
# <a href="https://colab.research.google.com/github/ChetanGoud77/PYTHON/blob/main/DAY_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/NewspaperData.csv")
data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Newspaper  34 non-null     object
#  1   daily      34 non-null     float64
#  2   sunday     34 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 948.0+ bytes

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# dtype: bool

# %%
data.shape
# Out:
# (34, 3)

# %%
data.isna().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
data.sample(10)
# Out:
#                       Newspaper    daily    sunday
# 5               Chicago Tribune  733.775  1133.249
# 12      Los Angeles Daily  News  185.736   202.614
# 27          Rocky Mountain News  374.009   432.502
# 32                Tampa Tribune  321.626   408.343
# 33              Washington Post  838.902  1165.567
# 31       St. Paul Pioneer Press  201.860   267.781
# 8           Des Moines Register  206.204   344.522
# 23             Pittsburgh Press  220.465   557.000
# 25  Providence Journal-Bulletin  197.120   268.060
# 15     Minneapolis Star Tribune  412.871   685.975

# %%
data.drop('Newspaper',axis=1).corr()
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(data['daily'])
# Out:
# <Axes: xlabel='daily', ylabel='Density'>

# %%
sns.distplot(data['sunday'])
plt.show()

# %%
import statsmodels.formula.api as smf
model = smf.ols('daily~sunday',data=data).fit()

# %%
sns.regplot(x='daily',y='sunday',data=data,ci=None);

# %%
data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['daily'].plot(kind='hist', bins=20, title='daily')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sunday'].plot(kind='hist', bins=20, title='sunday')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
model.params
# Out:
# Intercept    25.832125
# sunday        0.685265
# dtype: float64

# %%
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept     1.022773
# sunday       18.934840
# dtype: float64
#  Intercept    3.140853e-01
# sunday       6.016802e-19
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.9180596895873295, 0.9154990548869336)
